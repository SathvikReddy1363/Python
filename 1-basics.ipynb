# %%
## This is Sathvik Reddy's code for the 2024-25 season. He is a software engineer at Google and has been playing competitive programming for over 10 years. He has won several awards in various competitions and is known for his fast coding skills and problem-solving abilities.
'''
This is Sathvik Reddy's code for the 2024-25 season. He is a software engineer at Google and has been playing competitive programming for over 10 years.
 He has won several awards in various competitions and 
 is known for his fast coding skills and problem-solving abilities.
'''
# Out:
# "\nThis is Sathvik Reddy's code for the 2024-25 season. He is a software engineer at Google and has been playing competitive programming for over 10 years.\n He has won several awards in various competitions and \n is known for his fast coding skills and problem-solving abilities.\n"

# %%
name = "Sathvik Reddy"
Name = "Pasnuri"
print(name)
print(Name)
# Out:
# Sathvik Reddy
# Pasnuri

# %%
total = 1+2+2+3+4+5+\
    6+7+8+9
print(total)
# Out:
# 47

# %%
x=10;y=20;z=x+y
print(z)
# Out:
# 30

# %%
variable = 10
print(type(variable))
variable = "sathvik"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
