# %%
Lst =[]
print(type(Lst))
# Out:
# <class 'list'>

# %%
Lst = ["Sathvik", 1363, "Siri",2710, "Anshu"]
print(Lst)
# Out:
# ['Sathvik', 1363, 'Siri', 2710, 'Anshu']

# %%
Lst.append(9490077357)
print(Lst)
print(Lst[0])
