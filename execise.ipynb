# %%
n = int(input("Enter Number"))
for i in range(1,11):
  print(n, "*" ,i, "=" ,(n*i))
# Out:
# 5 * 1 = 5
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50

# %%
n = int(input("Enter number"))
total = 0
for i in range(1, n+1):
  total += i
print(total)
# Out:
# 15

# %%
n = input("ENter number")
print(sum(split(n)))
# Out:
# 1234
